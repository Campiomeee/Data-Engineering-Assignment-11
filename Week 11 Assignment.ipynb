# %%
import pandas as pd
import time
from pyspark.sql.functions import col, count, avg, sum as spark_sum, desc, when

# %%
# Check Spark version and cluster info
print(f"Spark version: {spark.version}")
print(f"Cluster configured successfully!")

# Check available datasets
dbutils.fs.ls("/databricks-datasets/")
# Out:
# Spark version: 4.0.0
# Cluster configured successfully!
# [FileInfo(path='dbfs:/databricks-datasets/COVID/', name='COVID/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/README.md', name='README.md', size=976, modificationTime=1596557781000),
#  FileInfo(path='dbfs:/databricks-datasets/Rdatasets/', name='Rdatasets/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/SPARK_README.md', name='SPARK_README.md', size=3359, modificationTime=1596557823000),
#  FileInfo(path='dbfs:/databricks-datasets/adult/', name='adult/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/airlines/', name='airlines/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/amazon/', name='amazon/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/asa/', name='asa/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/atlas_higgs/', name='atlas_higgs/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/bikeSharing/', name='bikeSharing/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/cctvVideos/', name='cctvVideos/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/credit-card-fraud/', name='credit-card-fraud/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/cs100/', name='cs100/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/cs110x/', name='cs110x/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/cs190/', name='cs190/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/data.gov/', name='data.gov/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/definitive-guide/', name='definitive-guide/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/delta-sharing/', name='delta-sharing/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/flights/', name='flights/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/flower_photos/', name='flower_photos/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/flowers/', name='flowers/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/genomics/', name='genomics/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/hail/', name='hail/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/identifying-campaign-effectiveness/', name='identifying-campaign-effectiveness/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/iot/', name='iot/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/iot-stream/', name='iot-stream/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/learning-spark/', name='learning-spark/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/learning-spark-v2/', name='learning-spark-v2/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/lending-club-loan-stats/', name='lending-club-loan-stats/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/med-images/', name='med-images/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/media/', name='media/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/mnist-digits/', name='mnist-digits/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/news20.binary/', name='news20.binary/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/nyctaxi/', name='nyctaxi/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/nyctaxi-with-zipcodes/', name='nyctaxi-with-zipcodes/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/online_retail/', name='online_retail/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/overlap-join/', name='overlap-join/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/power-plant/', name='power-plant/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/retail-org/', name='retail-org/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/rwe/', name='rwe/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/sai-summit-2019-sf/', name='sai-summit-2019-sf/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/sample_logs/', name='sample_logs/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/samples/', name='samples/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/sfo_customer_survey/', name='sfo_customer_survey/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/sms_spam_collection/', name='sms_spam_collection/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/songs/', name='songs/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/structured-streaming/', name='structured-streaming/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/timeseries/', name='timeseries/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/tpch/', name='tpch/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/travel_recommendations_realtime/', name='travel_recommendations_realtime/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/warmup/', name='warmup/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/weather/', name='weather/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/wiki/', name='wiki/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/wikipedia-datasets/', name='wikipedia-datasets/', size=0, modificationTime=1762918143456),
#  FileInfo(path='dbfs:/databricks-datasets/wine-quality/', name='wine-quality/', size=0, modificationTime=1762918143456)]

# %%
# %pip install -q kaggle 
# !mkdir -p ~/.kaggle
# !echo '{"username":"<KAGGLE_USER>","key":"<KAGGLE_KEY>"}' > ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download -d sobhanmoosavi/us-accidents -p /tmp --force
# !unzip -o /tmp/us-accidents.zip -d /tmp/us_accidents
# !ls -lh /tmp/us_accidents | head
# Out:
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Dataset URL: https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents
# License(s): CC-BY-NC-SA-4.0
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Inspect dataset size 
files = dbutils.fs.ls("/databricks-datasets/flights/departuredelays.csv")
total_bytes = sum(f.size for f in files)
total_gb_compressed = total_bytes / (1024**3)
estimated_uncompressed_gb = total_gb_compressed * 4  # average ×4 expansion
print(f"Compressed size: {total_gb_compressed:.2f} GB")
print(f"Estimated uncompressed size: {estimated_uncompressed_gb:.2f} GB (≈×4 expansion)")
# Out:
# Compressed size: 0.03 GB
# Estimated uncompressed size: 0.12 GB (≈×4 expansion)

# %%
# PYSPARK: Same task
path = "/databricks-datasets/flights/departuredelays.csv"

start = time.time()

df_spark = spark.read.csv(path, header=True, inferSchema=True)
result = df_spark.filter(col('delay') > 0) \
    .groupBy('origin') \
    .count() \
    .orderBy(desc('count')) \
    .limit(10)

result.show()

pyspark_time = time.time() - start

print(f"\n  PySpark: {pyspark_time:.2f} seconds")
# Out:
# +------+-----+
# |origin|count|
# +------+-----+
# |   ATL|41828|
# |   ORD|33812|
# |   DEN|30760|
# |   DFW|28706|
# |   LAX|22684|
# |   IAH|21009|
# |   PHX|17555|
# |   LAS|16938|
# |   SFO|16552|
# |   MCO|14189|
# +------+-----+
#
#
#   PySpark: 1.68 seconds

# %%
# Read built-in dataset
df = spark.read.csv(
    "/databricks-datasets/flights/departuredelays.csv",
    header=True,
    inferSchema=True
)

# 0.12 GB * 2^4 = 0.12 * 16 = 1.92 GB
for i in range(4):
    df = df.unionByName(df, allowMissingColumns=True)

    rows = df.count()              
    cols = len(df.columns)         
    print(f"{rows:,} rows × {cols} columns")
# Out:
# 2,783,156 rows × 5 columns
# 5,566,312 rows × 5 columns
# 11,132,624 rows × 5 columns
# 22,265,248 rows × 5 columns

# %%
from pyspark.sql import functions as F
from pyspark.sql.functions import broadcast

df.printSchema()
# Out:
# root
#  |-- date: integer (nullable = true)
#  |-- delay: integer (nullable = true)
#  |-- distance: integer (nullable = true)
#  |-- origin: string (nullable = true)
#  |-- destination: string (nullable = true)

# %%
from pyspark.sql import functions as F

df_t = (df
    # 1) Cast to string and keep only digits (defensive)
    .withColumn("date_digits", F.regexp_replace(F.col("date").cast("string"), "[^0-9]", ""))
    # 2) Left-pad to 8 chars (yyyyMMdd). e.g., 1011245 -> 01011245
    .withColumn("date_8", F.lpad(F.col("date_digits"), 8, "0"))
    # 3) Parse with try_to_date to avoid hard failures
    .withColumn("flight_date", F.expr("try_to_date(date_8, 'yyyyMMdd')"))
    .withColumn("year",  F.year("flight_date"))
    .withColumn("month", F.month("flight_date"))
    .withColumn("day",   F.dayofmonth("flight_date"))
    .withColumn("is_delayed", F.when(F.col("delay") > 0, 1).otherwise(0))
    .drop("date_digits","date_8")
)

# Quick peek (won't error if some dates are NULL)
df_t.select("flight_date","year","month","day","delay","distance","origin","destination","is_delayed").show(5)
# Out:
# +-----------+----+-----+----+-----+--------+------+-----------+----------+
# |flight_date|year|month| day|delay|distance|origin|destination|is_delayed|
# +-----------+----+-----+----+-----+--------+------+-----------+----------+
# |       NULL|NULL| NULL|NULL|    6|     602|   ABE|        ATL|         1|
# |       NULL|NULL| NULL|NULL|   -8|     369|   ABE|        DTW|         0|
# |       NULL|NULL| NULL|NULL|   -2|     602|   ABE|        ATL|         0|
# | 0102-06-05| 102|    6|   5|   -4|     602|   ABE|        ATL|         0|
# |       NULL|NULL| NULL|NULL|   -4|     602|   ABE|        ATL|         0|
# +-----------+----+-----+----+-----+--------+------+-----------+----------+
# only showing top 5 rows

# %%
df_f = (df_t
    .filter(F.col("flight_date").isNotNull())   # removes rows where parsing failed
    .filter(F.col("distance") > 0)
    .filter(F.col("origin").isNotNull() & F.col("destination").isNotNull()))
print("Rows after filters:", df_f.count())
# Out:
# Rows after filters: 4991904

# %%
dim_month = spark.createDataFrame(
    [(1,"Winter"),(2,"Winter"),(3,"Spring"),(4,"Spring"),(5,"Spring"),
     (6,"Summer"),(7,"Summer"),(8,"Summer"),
     (9,"Fall"),(10,"Fall"),(11,"Fall"),(12,"Winter")],
    ["month","season"]
)

df_enriched = df_f.join(broadcast(dim_month), on="month", how="left")
df_enriched.show(5)
# Out:
# +-----+-------+-----+--------+------+-----------+-----------+----+---+----------+------+
# |month|   date|delay|distance|origin|destination|flight_date|year|day|is_delayed|season|
# +-----+-------+-----+--------+------+-----------+-----------+----+---+----------+------+
# |    6|1020605|   -4|     602|   ABE|        ATL| 0102-06-05| 102|  5|         0|Summer|
# |    6|1030605|    0|     602|   ABE|        ATL| 0103-06-05| 103|  5|         0|Summer|
# |    6|1040605|   28|     602|   ABE|        ATL| 0104-06-05| 104|  5|         1|Summer|
# |    6|1050605|    9|     602|   ABE|        ATL| 0105-06-05| 105|  5|         1|Summer|
# |   12|1061215|   -6|     602|   ABE|        ATL| 0106-12-15| 106| 15|         0|Winter|
# +-----+-------+-----+--------+------+-----------+-----------+----+---+----------+------+
# only showing top 5 rows

# %%
agg_origin = (df_enriched
  .groupBy("year","month","origin")
  .agg(
      F.count("*").alias("flights"),
      F.avg("delay").alias("avg_delay_min"),
      F.sum("is_delayed").alias("delayed_flights"),
      F.avg("distance").alias("avg_distance")
  )
  .withColumn("delay_rate", F.col("delayed_flights")/F.col("flights"))
)

agg_origin.orderBy(F.desc("flights")).show(10, truncate=False)
# Out:
# +----+-----+------+-------+-------------------+---------------+------------------+-------------------+
# |year|month|origin|flights|avg_delay_min      |delayed_flights|avg_distance      |delay_rate         |
# +----+-----+------+-------+-------------------+---------------+------------------+-------------------+
# |102 |8    |ATL   |1024   |9.5625             |480            |621.40625         |0.46875            |
# |103 |8    |ATL   |1024   |12.625             |512            |625.78125         |0.5                |
# |106 |8    |ATL   |960    |11.35              |496            |642.9333333333333 |0.5166666666666667 |
# |105 |8    |ATL   |896    |9.803571428571429  |464            |644.8214285714286 |0.5178571428571429 |
# |207 |12   |ATL   |848    |9.641509433962264  |464            |509.20754716981133|0.5471698113207547 |
# |127 |12   |ATL   |848    |1.2641509433962264 |160            |509.20754716981133|0.18867924528301888|
# |130 |12   |ATL   |848    |25.037735849056602 |288            |506.64150943396226|0.33962264150943394|
# |209 |12   |ATL   |832    |1.2884615384615385 |240            |517.1730769230769 |0.28846153846153844|
# |120 |12   |ATL   |832    |-0.5192307692307693|176            |507.9423076923077 |0.21153846153846154|
# |220 |12   |ATL   |832    |5.5                |336            |556.25            |0.40384615384615385|
# +----+-----+------+-------+-------------------+---------------+------------------+-------------------+
# only showing top 10 rows

# %%
agg_route = (df_enriched
  .groupBy("year","origin","destination","season")
  .agg(
      F.count("*").alias("flights"),
      F.avg("delay").alias("avg_delay_min"),
      F.expr("percentile_approx(delay, 0.9)").alias("p90_delay_min")
  )
)

agg_route.orderBy(F.desc("flights")).show(10, truncate=False)
# Out:
# +----+------+-----------+------+-------+-------------------+-------------+
# |year|origin|destination|season|flights|avg_delay_min      |p90_delay_min|
# +----+------+-----------+------+-------+-------------------+-------------+
# |107 |LAS   |LAX        |Summer|96     |0.3333333333333333 |10           |
# |207 |LAS   |LAX        |Summer|96     |4.666666666666667  |40           |
# |120 |LAS   |LAX        |Summer|96     |9.0                |62           |
# |110 |LAS   |LAX        |Summer|96     |-0.8333333333333334|3            |
# |113 |LAS   |LAX        |Summer|96     |-2.6666666666666665|8            |
# |216 |LAS   |LAX        |Fall  |96     |0.6666666666666666 |12           |
# |124 |LAS   |LAX        |Summer|96     |1.6666666666666667 |32           |
# |102 |LAX   |DEN        |Summer|96     |-0.8333333333333334|5            |
# |106 |LAX   |DEN        |Summer|96     |10.0               |35           |
# |127 |LAS   |LAX        |Summer|96     |-4.0               |-2           |
# +----+------+-----------+------+-------+-------------------+-------------+
# only showing top 10 rows

# %%
# Compute data-driven thresholds
route_thresh  = agg_route.approxQuantile("flights", [0.50], 0.05)[0]   # median
origin_thresh = agg_origin.approxQuantile("flights", [0.50], 0.05)[0]

print("Adaptive thresholds — route:", route_thresh, " origin-month:", origin_thresh)

# Recreate the two “queries” via DataFrame API
q1 = (agg_route
      .filter(F.col("flights") >= F.lit(route_thresh))
      .select("year","season","origin","destination","flights",
              F.round(F.col("avg_delay_min"), 1).alias("avg_delay_min"))
      .orderBy(F.desc("avg_delay_min"))
      .limit(20))

q1.show(truncate=False)


# SQL #2: Best origins by on-time rate (min 1k flights in a month)
q2 = spark.sql("""
SELECT year, month, origin, flights,
       ROUND(1 - delay_rate, 3) AS on_time_rate
FROM agg_origin
WHERE flights >= 1000
ORDER BY on_time_rate DESC, flights DESC
LIMIT 20
""")
q2.show(truncate=False)
# Out:
# Adaptive thresholds — route: 16.0  origin-month: 32.0
# +----+------+------+-----------+-------+-------------+
# |year|season|origin|destination|flights|avg_delay_min|
# +----+------+------+-----------+-------+-------------+
# |309 |Summer|TPA   |DFW        |16     |1642.0       |
# |303 |Winter|PDX   |DFW        |16     |1553.0       |
# |130 |Fall  |EGE   |JFK        |16     |1500.0       |
# |115 |Summer|ONT   |DFW        |16     |1496.0       |
# |130 |Summer|EGE   |DFW        |16     |1482.0       |
# |121 |Summer|IAD   |DFW        |16     |1444.0       |
# |205 |Summer|LAS   |MIA        |16     |1418.0       |
# |203 |Summer|FAT   |DFW        |16     |1417.0       |
# |111 |Summer|PSP   |DFW        |16     |1404.0       |
# |118 |Winter|PBI   |ORD        |16     |1151.0       |
# |211 |Winter|PBI   |ORD        |16     |1128.0       |
# |223 |Spring|BNA   |ATL        |16     |1056.0       |
# |314 |Summer|DEN   |MSP        |16     |982.0        |
# |127 |Summer|MKE   |DFW        |16     |951.0        |
# |211 |Summer|GUM   |HNL        |16     |914.0        |
# |315 |Summer|LAS   |MIA        |16     |912.0        |
# |329 |Fall  |MIA   |ORD        |16     |847.0        |
# |212 |Summer|SJT   |DFW        |16     |788.0        |
# |118 |Summer|BNA   |DFW        |32     |785.0        |
# |303 |Spring|TYR   |IAH        |16     |778.0        |
# +----+------+------+-----------+-------+-------------+
#
# +----+-----+------+-------+------------+
# |year|month|origin|flights|on_time_rate|
# +----+-----+------+-------+------------+
# |102 |8    |ATL   |1024   |0.531       |
# |103 |8    |ATL   |1024   |0.5         |
# +----+-----+------+-------+------------+

# %%
print("=== df_enriched ===")
df_enriched.explain(mode="formatted")

print("\n=== agg_origin ===")
agg_origin.explain(mode="formatted")

print("\n=== q1 ===")
q1.explain(mode="formatted")
# Out:
# === df_enriched ===
# == Physical Plan ==
# AdaptiveSparkPlan (92)
# +- == Initial Plan ==
#    ColumnarToRow (91)
#    +- PhotonResultStage (90)
#       +- PhotonProject (89)
#          +- PhotonBroadcastHashJoin LeftOuter (88)
#             :- PhotonUnion (81)
#             :  :- PhotonProject (5)
#             :  :  +- PhotonProject (4)
#             :  :     +- PhotonFilter (3)
#             :  :        +- PhotonRowToColumnar (2)
#             :  :           +- Scan csv  (1)
#             :  :- PhotonProject (10)
#             :  :  +- PhotonProject (9)
#             :  :     +- PhotonFilter (8)
#             :  :        +- PhotonRowToColumnar (7)
#             :  :           +- Scan csv  (6)
#             :  :- PhotonProject (15)
#             :  :  +- PhotonProject (14)
#             :  :     +- PhotonFilter (13)
#             :  :        +- PhotonRowToColumnar (12)
#             :  :           +- Scan csv  (11)
#             :  :- PhotonProject (20)
#             :  :  +- PhotonProject (19)
#             :  :     +- PhotonFilter (18)
#             :  :        +- PhotonRowToColumnar (17)
#             :  :           +- Scan csv  (16)
#             :  :- PhotonProject (25)
#             :  :  +- PhotonProject (24)
#             :  :     +- PhotonFilter (23)
#             :  :        +- PhotonRowToColumnar (22)
#             :  :           +- Scan csv  (21)
#             :  :- PhotonProject (30)
#             :  :  +- PhotonProject (29)
#             :  :     +- PhotonFilter (28)
#             :  :        +- PhotonRowToColumnar (27)
#             :  :           +- Scan csv  (26)
#             :  :- PhotonProject (35)
#             :  :  +- PhotonProject (34)
#             :  :     +- PhotonFilter (33)
#             :  :        +- PhotonRowToColumnar (32)
#             :  :           +- Scan csv  (31)
#             :  :- PhotonProject (40)
#             :  :  +- PhotonProject (39)
#             :  :     +- PhotonFilter (38)
#             :  :        +- PhotonRowToColumnar (37)
#             :  :           +- Scan csv  (36)
#             :  :- PhotonProject (45)
#             :  :  +- PhotonProject (44)
#             :  :     +- PhotonFilter (43)
#             :  :        +- PhotonRowToColumnar (42)
#             :  :           +- Scan csv  (41)
#             :  :- PhotonProject (50)
#             :  :  +- PhotonProject (49)
#             :  :     +- PhotonFilter (48)
#             :  :        +- PhotonRowToColumnar (47)
#             :  :           +- Scan csv  (46)
#             :  :- PhotonProject (55)
#             :  :  +- PhotonProject (54)
#             :  :     +- PhotonFilter (53)
#             :  :        +- PhotonRowToColumnar (52)
#             :  :           +- Scan csv  (51)
#             :  :- PhotonProject (60)
#             :  :  +- PhotonProject (59)
#             :  :     +- PhotonFilter (58)
#             :  :        +- PhotonRowToColumnar (57)
#             :  :           +- Scan csv  (56)
#             :  :- PhotonProject (65)
#             :  :  +- PhotonProject (64)
#             :  :     +- PhotonFilter (63)
#             :  :        +- PhotonRowToColumnar (62)
#             :  :           +- Scan csv  (61)
#             :  :- PhotonProject (70)
#             :  :  +- PhotonProject (69)
#             :  :     +- PhotonFilter (68)
#             :  :        +- PhotonRowToColumnar (67)
#             :  :           +- Scan csv  (66)
#             :  :- PhotonProject (75)
#             :  :  +- PhotonProject (74)
#             :  :     +- PhotonFilter (73)
#             :  :        +- PhotonRowToColumnar (72)
#             :  :           +- Scan csv  (71)
#             :  +- PhotonProject (80)
#             :     +- PhotonProject (79)
#             :        +- PhotonFilter (78)
#             :           +- PhotonRowToColumnar (77)
#             :              +- Scan csv  (76)
#             +- PhotonShuffleExchangeSource (87)
#                +- PhotonShuffleMapStage (86)
#                   +- PhotonShuffleExchangeSink (85)
#                      +- PhotonFilter (84)
#                         +- PhotonRowToColumnar (83)
#                            +- LocalTableScan (82)
#
#
# (1) Scan csv
# Output [5]: [date#23038, delay#23039, distance#23040, origin#23041, destination#23042]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (2) PhotonRowToColumnar
# Input [5]: [date#23038, delay#23039, distance#23040, origin#23041, destination#23042]
#
# (3) PhotonFilter
# Input [5]: [date#23038, delay#23039, distance#23040, origin#23041, destination#23042]
# Arguments: ((((isnotnull(distance#23040) AND (distance#23040 > 0)) AND isnotnull(origin#23041)) AND isnotnull(destination#23042)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23038 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (4) PhotonProject
# Input [5]: [date#23038, delay#23039, distance#23040, origin#23041, destination#23042]
# Arguments: [date#23038, delay#23039, distance#23040, origin#23041, destination#23042, cast(gettimestamp(lpad(regexp_replace(cast(date#23038 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#23675]
#
# (5) PhotonProject
# Input [6]: [date#23038, delay#23039, distance#23040, origin#23041, destination#23042, flight_date#23675]
# Arguments: [date#23038, delay#23039, distance#23040, origin#23041, destination#23042, flight_date#23675, year(flight_date#23675) AS year#23677, month(flight_date#23675) AS month#23679, dayofmonth(flight_date#23675) AS day#23681, CASE WHEN (delay#23039 > 0) THEN 1 ELSE 0 END AS is_delayed#23683]
#
# (6) Scan csv
# Output [5]: [date#23587, delay#23588, distance#23589, origin#23590, destination#23591]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (7) PhotonRowToColumnar
# Input [5]: [date#23587, delay#23588, distance#23589, origin#23590, destination#23591]
#
# (8) PhotonFilter
# Input [5]: [date#23587, delay#23588, distance#23589, origin#23590, destination#23591]
# Arguments: ((((isnotnull(distance#23589) AND (distance#23589 > 0)) AND isnotnull(origin#23590)) AND isnotnull(destination#23591)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23587 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (9) PhotonProject
# Input [5]: [date#23587, delay#23588, distance#23589, origin#23590, destination#23591]
# Arguments: [date#23587, delay#23588, distance#23589, origin#23590, destination#23591, cast(gettimestamp(lpad(regexp_replace(cast(date#23587 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#25978]
#
# (10) PhotonProject
# Input [6]: [date#23587, delay#23588, distance#23589, origin#23590, destination#23591, flight_date#25978]
# Arguments: [date#23587, delay#23588, distance#23589, origin#23590, destination#23591, flight_date#25978, year(flight_date#25978) AS year#25993, month(flight_date#25978) AS month#25994, dayofmonth(flight_date#25978) AS day#25995, CASE WHEN (delay#23588 > 0) THEN 1 ELSE 0 END AS is_delayed#25996]
#
# (11) Scan csv
# Output [5]: [date#23592, delay#23593, distance#23594, origin#23595, destination#23596]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (12) PhotonRowToColumnar
# Input [5]: [date#23592, delay#23593, distance#23594, origin#23595, destination#23596]
#
# (13) PhotonFilter
# Input [5]: [date#23592, delay#23593, distance#23594, origin#23595, destination#23596]
# Arguments: ((((isnotnull(distance#23594) AND (distance#23594 > 0)) AND isnotnull(origin#23595)) AND isnotnull(destination#23596)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23592 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (14) PhotonProject
# Input [5]: [date#23592, delay#23593, distance#23594, origin#23595, destination#23596]
# Arguments: [date#23592, delay#23593, distance#23594, origin#23595, destination#23596, cast(gettimestamp(lpad(regexp_replace(cast(date#23592 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#25979]
#
# (15) PhotonProject
# Input [6]: [date#23592, delay#23593, distance#23594, origin#23595, destination#23596, flight_date#25979]
# Arguments: [date#23592, delay#23593, distance#23594, origin#23595, destination#23596, flight_date#25979, year(flight_date#25979) AS year#25997, month(flight_date#25979) AS month#25998, dayofmonth(flight_date#25979) AS day#25999, CASE WHEN (delay#23593 > 0) THEN 1 ELSE 0 END AS is_delayed#26000]
#
# (16) Scan csv
# Output [5]: [date#23597, delay#23598, distance#23599, origin#23600, destination#23601]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (17) PhotonRowToColumnar
# Input [5]: [date#23597, delay#23598, distance#23599, origin#23600, destination#23601]
#
# (18) PhotonFilter
# Input [5]: [date#23597, delay#23598, distance#23599, origin#23600, destination#23601]
# Arguments: ((((isnotnull(distance#23599) AND (distance#23599 > 0)) AND isnotnull(origin#23600)) AND isnotnull(destination#23601)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23597 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (19) PhotonProject
# Input [5]: [date#23597, delay#23598, distance#23599, origin#23600, destination#23601]
# Arguments: [date#23597, delay#23598, distance#23599, origin#23600, destination#23601, cast(gettimestamp(lpad(regexp_replace(cast(date#23597 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#25980]
#
# (20) PhotonProject
# Input [6]: [date#23597, delay#23598, distance#23599, origin#23600, destination#23601, flight_date#25980]
# Arguments: [date#23597, delay#23598, distance#23599, origin#23600, destination#23601, flight_date#25980, year(flight_date#25980) AS year#26001, month(flight_date#25980) AS month#26002, dayofmonth(flight_date#25980) AS day#26003, CASE WHEN (delay#23598 > 0) THEN 1 ELSE 0 END AS is_delayed#26004]
#
# (21) Scan csv
# Output [5]: [date#23602, delay#23603, distance#23604, origin#23605, destination#23606]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (22) PhotonRowToColumnar
# Input [5]: [date#23602, delay#23603, distance#23604, origin#23605, destination#23606]
#
# (23) PhotonFilter
# Input [5]: [date#23602, delay#23603, distance#23604, origin#23605, destination#23606]
# Arguments: ((((isnotnull(distance#23604) AND (distance#23604 > 0)) AND isnotnull(origin#23605)) AND isnotnull(destination#23606)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23602 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (24) PhotonProject
# Input [5]: [date#23602, delay#23603, distance#23604, origin#23605, destination#23606]
# Arguments: [date#23602, delay#23603, distance#23604, origin#23605, destination#23606, cast(gettimestamp(lpad(regexp_replace(cast(date#23602 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#25981]
#
# (25) PhotonProject
# Input [6]: [date#23602, delay#23603, distance#23604, origin#23605, destination#23606, flight_date#25981]
# Arguments: [date#23602, delay#23603, distance#23604, origin#23605, destination#23606, flight_date#25981, year(flight_date#25981) AS year#26005, month(flight_date#25981) AS month#26006, dayofmonth(flight_date#25981) AS day#26007, CASE WHEN (delay#23603 > 0) THEN 1 ELSE 0 END AS is_delayed#26008]
#
# (26) Scan csv
# Output [5]: [date#23607, delay#23608, distance#23609, origin#23610, destination#23611]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (27) PhotonRowToColumnar
# Input [5]: [date#23607, delay#23608, distance#23609, origin#23610, destination#23611]
#
# (28) PhotonFilter
# Input [5]: [date#23607, delay#23608, distance#23609, origin#23610, destination#23611]
# Arguments: ((((isnotnull(distance#23609) AND (distance#23609 > 0)) AND isnotnull(origin#23610)) AND isnotnull(destination#23611)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23607 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (29) PhotonProject
# Input [5]: [date#23607, delay#23608, distance#23609, origin#23610, destination#23611]
# Arguments: [date#23607, delay#23608, distance#23609, origin#23610, destination#23611, cast(gettimestamp(lpad(regexp_replace(cast(date#23607 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#25982]
#
# (30) PhotonProject
# Input [6]: [date#23607, delay#23608, distance#23609, origin#23610, destination#23611, flight_date#25982]
# Arguments: [date#23607, delay#23608, distance#23609, origin#23610, destination#23611, flight_date#25982, year(flight_date#25982) AS year#26009, month(flight_date#25982) AS month#26010, dayofmonth(flight_date#25982) AS day#26011, CASE WHEN (delay#23608 > 0) THEN 1 ELSE 0 END AS is_delayed#26012]
#
# (31) Scan csv
# Output [5]: [date#23612, delay#23613, distance#23614, origin#23615, destination#23616]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (32) PhotonRowToColumnar
# Input [5]: [date#23612, delay#23613, distance#23614, origin#23615, destination#23616]
#
# (33) PhotonFilter
# Input [5]: [date#23612, delay#23613, distance#23614, origin#23615, destination#23616]
# Arguments: ((((isnotnull(distance#23614) AND (distance#23614 > 0)) AND isnotnull(origin#23615)) AND isnotnull(destination#23616)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23612 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (34) PhotonProject
# Input [5]: [date#23612, delay#23613, distance#23614, origin#23615, destination#23616]
# Arguments: [date#23612, delay#23613, distance#23614, origin#23615, destination#23616, cast(gettimestamp(lpad(regexp_replace(cast(date#23612 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#25983]
#
# (35) PhotonProject
# Input [6]: [date#23612, delay#23613, distance#23614, origin#23615, destination#23616, flight_date#25983]
# Arguments: [date#23612, delay#23613, distance#23614, origin#23615, destination#23616, flight_date#25983, year(flight_date#25983) AS year#26013, month(flight_date#25983) AS month#26014, dayofmonth(flight_date#25983) AS day#26015, CASE WHEN (delay#23613 > 0) THEN 1 ELSE 0 END AS is_delayed#26016]
#
# (36) Scan csv
# Output [5]: [date#23617, delay#23618, distance#23619, origin#23620, destination#23621]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (37) PhotonRowToColumnar
# Input [5]: [date#23617, delay#23618, distance#23619, origin#23620, destination#23621]
#
# (38) PhotonFilter
# Input [5]: [date#23617, delay#23618, distance#23619, origin#23620, destination#23621]
# Arguments: ((((isnotnull(distance#23619) AND (distance#23619 > 0)) AND isnotnull(origin#23620)) AND isnotnull(destination#23621)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23617 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (39) PhotonProject
# Input [5]: [date#23617, delay#23618, distance#23619, origin#23620, destination#23621]
# Arguments: [date#23617, delay#23618, distance#23619, origin#23620, destination#23621, cast(gettimestamp(lpad(regexp_replace(cast(date#23617 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#25984]
#
# (40) PhotonProject
# Input [6]: [date#23617, delay#23618, distance#23619, origin#23620, destination#23621, flight_date#25984]
# Arguments: [date#23617, delay#23618, distance#23619, origin#23620, destination#23621, flight_date#25984, year(flight_date#25984) AS year#26017, month(flight_date#25984) AS month#26018, dayofmonth(flight_date#25984) AS day#26019, CASE WHEN (delay#23618 > 0) THEN 1 ELSE 0 END AS is_delayed#26020]
#
# (41) Scan csv
# Output [5]: [date#23622, delay#23623, distance#23624, origin#23625, destination#23626]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (42) PhotonRowToColumnar
# Input [5]: [date#23622, delay#23623, distance#23624, origin#23625, destination#23626]
#
# (43) PhotonFilter
# Input [5]: [date#23622, delay#23623, distance#23624, origin#23625, destination#23626]
# Arguments: ((((isnotnull(distance#23624) AND (distance#23624 > 0)) AND isnotnull(origin#23625)) AND isnotnull(destination#23626)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23622 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (44) PhotonProject
# Input [5]: [date#23622, delay#23623, distance#23624, origin#23625, destination#23626]
# Arguments: [date#23622, delay#23623, distance#23624, origin#23625, destination#23626, cast(gettimestamp(lpad(regexp_replace(cast(date#23622 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#25985]
#
# (45) PhotonProject
# Input [6]: [date#23622, delay#23623, distance#23624, origin#23625, destination#23626, flight_date#25985]
# Arguments: [date#23622, delay#23623, distance#23624, origin#23625, destination#23626, flight_date#25985, year(flight_date#25985) AS year#26021, month(flight_date#25985) AS month#26022, dayofmonth(flight_date#25985) AS day#26023, CASE WHEN (delay#23623 > 0) THEN 1 ELSE 0 END AS is_delayed#26024]
#
# (46) Scan csv
# Output [5]: [date#23627, delay#23628, distance#23629, origin#23630, destination#23631]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (47) PhotonRowToColumnar
# Input [5]: [date#23627, delay#23628, distance#23629, origin#23630, destination#23631]
#
# (48) PhotonFilter
# Input [5]: [date#23627, delay#23628, distance#23629, origin#23630, destination#23631]
# Arguments: ((((isnotnull(distance#23629) AND (distance#23629 > 0)) AND isnotnull(origin#23630)) AND isnotnull(destination#23631)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23627 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (49) PhotonProject
# Input [5]: [date#23627, delay#23628, distance#23629, origin#23630, destination#23631]
# Arguments: [date#23627, delay#23628, distance#23629, origin#23630, destination#23631, cast(gettimestamp(lpad(regexp_replace(cast(date#23627 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#25986]
#
# (50) PhotonProject
# Input [6]: [date#23627, delay#23628, distance#23629, origin#23630, destination#23631, flight_date#25986]
# Arguments: [date#23627, delay#23628, distance#23629, origin#23630, destination#23631, flight_date#25986, year(flight_date#25986) AS year#26025, month(flight_date#25986) AS month#26026, dayofmonth(flight_date#25986) AS day#26027, CASE WHEN (delay#23628 > 0) THEN 1 ELSE 0 END AS is_delayed#26028]
#
# (51) Scan csv
# Output [5]: [date#23632, delay#23633, distance#23634, origin#23635, destination#23636]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (52) PhotonRowToColumnar
# Input [5]: [date#23632, delay#23633, distance#23634, origin#23635, destination#23636]
#
# (53) PhotonFilter
# Input [5]: [date#23632, delay#23633, distance#23634, origin#23635, destination#23636]
# Arguments: ((((isnotnull(distance#23634) AND (distance#23634 > 0)) AND isnotnull(origin#23635)) AND isnotnull(destination#23636)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23632 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (54) PhotonProject
# Input [5]: [date#23632, delay#23633, distance#23634, origin#23635, destination#23636]
# Arguments: [date#23632, delay#23633, distance#23634, origin#23635, destination#23636, cast(gettimestamp(lpad(regexp_replace(cast(date#23632 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#25987]
#
# (55) PhotonProject
# Input [6]: [date#23632, delay#23633, distance#23634, origin#23635, destination#23636, flight_date#25987]
# Arguments: [date#23632, delay#23633, distance#23634, origin#23635, destination#23636, flight_date#25987, year(flight_date#25987) AS year#26029, month(flight_date#25987) AS month#26030, dayofmonth(flight_date#25987) AS day#26031, CASE WHEN (delay#23633 > 0) THEN 1 ELSE 0 END AS is_delayed#26032]
#
# (56) Scan csv
# Output [5]: [date#23637, delay#23638, distance#23639, origin#23640, destination#23641]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (57) PhotonRowToColumnar
# Input [5]: [date#23637, delay#23638, distance#23639, origin#23640, destination#23641]
#
# (58) PhotonFilter
# Input [5]: [date#23637, delay#23638, distance#23639, origin#23640, destination#23641]
# Arguments: ((((isnotnull(distance#23639) AND (distance#23639 > 0)) AND isnotnull(origin#23640)) AND isnotnull(destination#23641)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23637 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (59) PhotonProject
# Input [5]: [date#23637, delay#23638, distance#23639, origin#23640, destination#23641]
# Arguments: [date#23637, delay#23638, distance#23639, origin#23640, destination#23641, cast(gettimestamp(lpad(regexp_replace(cast(date#23637 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#25988]
#
# (60) PhotonProject
# Input [6]: [date#23637, delay#23638, distance#23639, origin#23640, destination#23641, flight_date#25988]
# Arguments: [date#23637, delay#23638, distance#23639, origin#23640, destination#23641, flight_date#25988, year(flight_date#25988) AS year#26033, month(flight_date#25988) AS month#26034, dayofmonth(flight_date#25988) AS day#26035, CASE WHEN (delay#23638 > 0) THEN 1 ELSE 0 END AS is_delayed#26036]
#
# (61) Scan csv
# Output [5]: [date#23642, delay#23643, distance#23644, origin#23645, destination#23646]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (62) PhotonRowToColumnar
# Input [5]: [date#23642, delay#23643, distance#23644, origin#23645, destination#23646]
#
# (63) PhotonFilter
# Input [5]: [date#23642, delay#23643, distance#23644, origin#23645, destination#23646]
# Arguments: ((((isnotnull(distance#23644) AND (distance#23644 > 0)) AND isnotnull(origin#23645)) AND isnotnull(destination#23646)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23642 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (64) PhotonProject
# Input [5]: [date#23642, delay#23643, distance#23644, origin#23645, destination#23646]
# Arguments: [date#23642, delay#23643, distance#23644, origin#23645, destination#23646, cast(gettimestamp(lpad(regexp_replace(cast(date#23642 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#25989]
#
# (65) PhotonProject
# Input [6]: [date#23642, delay#23643, distance#23644, origin#23645, destination#23646, flight_date#25989]
# Arguments: [date#23642, delay#23643, distance#23644, origin#23645, destination#23646, flight_date#25989, year(flight_date#25989) AS year#26037, month(flight_date#25989) AS month#26038, dayofmonth(flight_date#25989) AS day#26039, CASE WHEN (delay#23643 > 0) THEN 1 ELSE 0 END AS is_delayed#26040]
#
# (66) Scan csv
# Output [5]: [date#23647, delay#23648, distance#23649, origin#23650, destination#23651]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (67) PhotonRowToColumnar
# Input [5]: [date#23647, delay#23648, distance#23649, origin#23650, destination#23651]
#
# (68) PhotonFilter
# Input [5]: [date#23647, delay#23648, distance#23649, origin#23650, destination#23651]
# Arguments: ((((isnotnull(distance#23649) AND (distance#23649 > 0)) AND isnotnull(origin#23650)) AND isnotnull(destination#23651)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23647 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (69) PhotonProject
# Input [5]: [date#23647, delay#23648, distance#23649, origin#23650, destination#23651]
# Arguments: [date#23647, delay#23648, distance#23649, origin#23650, destination#23651, cast(gettimestamp(lpad(regexp_replace(cast(date#23647 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#25990]
#
# (70) PhotonProject
# Input [6]: [date#23647, delay#23648, distance#23649, origin#23650, destination#23651, flight_date#25990]
# Arguments: [date#23647, delay#23648, distance#23649, origin#23650, destination#23651, flight_date#25990, year(flight_date#25990) AS year#26041, month(flight_date#25990) AS month#26042, dayofmonth(flight_date#25990) AS day#26043, CASE WHEN (delay#23648 > 0) THEN 1 ELSE 0 END AS is_delayed#26044]
#
# (71) Scan csv
# Output [5]: [date#23652, delay#23653, distance#23654, origin#23655, destination#23656]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (72) PhotonRowToColumnar
# Input [5]: [date#23652, delay#23653, distance#23654, origin#23655, destination#23656]
#
# (73) PhotonFilter
# Input [5]: [date#23652, delay#23653, distance#23654, origin#23655, destination#23656]
# Arguments: ((((isnotnull(distance#23654) AND (distance#23654 > 0)) AND isnotnull(origin#23655)) AND isnotnull(destination#23656)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23652 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (74) PhotonProject
# Input [5]: [date#23652, delay#23653, distance#23654, origin#23655, destination#23656]
# Arguments: [date#23652, delay#23653, distance#23654, origin#23655, destination#23656, cast(gettimestamp(lpad(regexp_replace(cast(date#23652 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#25991]
#
# (75) PhotonProject
# Input [6]: [date#23652, delay#23653, distance#23654, origin#23655, destination#23656, flight_date#25991]
# Arguments: [date#23652, delay#23653, distance#23654, origin#23655, destination#23656, flight_date#25991, year(flight_date#25991) AS year#26045, month(flight_date#25991) AS month#26046, dayofmonth(flight_date#25991) AS day#26047, CASE WHEN (delay#23653 > 0) THEN 1 ELSE 0 END AS is_delayed#26048]
#
# (76) Scan csv
# Output [5]: [date#23657, delay#23658, distance#23659, origin#23660, destination#23661]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (77) PhotonRowToColumnar
# Input [5]: [date#23657, delay#23658, distance#23659, origin#23660, destination#23661]
#
# (78) PhotonFilter
# Input [5]: [date#23657, delay#23658, distance#23659, origin#23660, destination#23661]
# Arguments: ((((isnotnull(distance#23659) AND (distance#23659 > 0)) AND isnotnull(origin#23660)) AND isnotnull(destination#23661)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23657 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (79) PhotonProject
# Input [5]: [date#23657, delay#23658, distance#23659, origin#23660, destination#23661]
# Arguments: [date#23657, delay#23658, distance#23659, origin#23660, destination#23661, cast(gettimestamp(lpad(regexp_replace(cast(date#23657 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#25992]
#
# (80) PhotonProject
# Input [6]: [date#23657, delay#23658, distance#23659, origin#23660, destination#23661, flight_date#25992]
# Arguments: [date#23657, delay#23658, distance#23659, origin#23660, destination#23661, flight_date#25992, year(flight_date#25992) AS year#26049, month(flight_date#25992) AS month#26050, dayofmonth(flight_date#25992) AS day#26051, CASE WHEN (delay#23658 > 0) THEN 1 ELSE 0 END AS is_delayed#26052]
#
# (81) PhotonUnion
# Arguments: Generic
#
# (82) LocalTableScan
# Output [2]: [month#25961L, season#25962]
# Arguments: [month#25961L, season#25962]
#
# (83) PhotonRowToColumnar
# Input [2]: [month#25961L, season#25962]
#
# (84) PhotonFilter
# Input [2]: [month#25961L, season#25962]
# Arguments: isnotnull(month#25961L)
#
# (85) PhotonShuffleExchangeSink
# Input [2]: [month#25961L, season#25962]
# Arguments: SinglePartition
#
# (86) PhotonShuffleMapStage
# Input [2]: [month#25961L, season#25962]
# Arguments: EXECUTOR_BROADCAST, [id=#89159]
#
# (87) PhotonShuffleExchangeSource
# Input [2]: [month#25961L, season#25962]
#
# (88) PhotonBroadcastHashJoin
# Left keys [1]: [cast(month#23679 as bigint)]
# Right keys [1]: [month#25961L]
# Join type: LeftOuter
# Join condition: None
#
# (89) PhotonProject
# Input [12]: [date#23038, delay#23039, distance#23040, origin#23041, destination#23042, flight_date#23675, year#23677, month#23679, day#23681, is_delayed#23683, month#25961L, season#25962]
# Arguments: [month#23679, date#23038, delay#23039, distance#23040, origin#23041, destination#23042, flight_date#23675, year#23677, day#23681, is_delayed#23683, season#25962]
#
# (90) PhotonResultStage
# Input [11]: [month#23679, date#23038, delay#23039, distance#23040, origin#23041, destination#23042, flight_date#23675, year#23677, day#23681, is_delayed#23683, season#25962]
#
# (91) ColumnarToRow
# Input [11]: [month#23679, date#23038, delay#23039, distance#23040, origin#23041, destination#23042, flight_date#23675, year#23677, day#23681, is_delayed#23683, season#25962]
#
# (92) AdaptiveSparkPlan
# Output [11]: [month#23679, date#23038, delay#23039, distance#23040, origin#23041, destination#23042, flight_date#23675, year#23677, day#23681, is_delayed#23683, season#25962]
# Arguments: isFinalPlan=false
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.
#
# === agg_origin ===
# == Physical Plan ==
# AdaptiveSparkPlan (99)
# +- == Initial Plan ==
#    ColumnarToRow (98)
#    +- PhotonResultStage (97)
#       +- PhotonProject (96)
#          +- PhotonGroupingAgg (95)
#             +- PhotonShuffleExchangeSource (94)
#                +- PhotonShuffleMapStage (93)
#                   +- PhotonShuffleExchangeSink (92)
#                      +- PhotonGroupingAgg (91)
#                         +- PhotonProject (90)
#                            +- PhotonBroadcastHashJoin LeftOuter (89)
#                               :- PhotonGroupingAgg (82)
#                               :  +- PhotonUnion (81)
#                               :     :- PhotonProject (5)
#                               :     :  +- PhotonProject (4)
#                               :     :     +- PhotonFilter (3)
#                               :     :        +- PhotonRowToColumnar (2)
#                               :     :           +- Scan csv  (1)
#                               :     :- PhotonProject (10)
#                               :     :  +- PhotonProject (9)
#                               :     :     +- PhotonFilter (8)
#                               :     :        +- PhotonRowToColumnar (7)
#                               :     :           +- Scan csv  (6)
#                               :     :- PhotonProject (15)
#                               :     :  +- PhotonProject (14)
#                               :     :     +- PhotonFilter (13)
#                               :     :        +- PhotonRowToColumnar (12)
#                               :     :           +- Scan csv  (11)
#                               :     :- PhotonProject (20)
#                               :     :  +- PhotonProject (19)
#                               :     :     +- PhotonFilter (18)
#                               :     :        +- PhotonRowToColumnar (17)
#                               :     :           +- Scan csv  (16)
#                               :     :- PhotonProject (25)
#                               :     :  +- PhotonProject (24)
#                               :     :     +- PhotonFilter (23)
#                               :     :        +- PhotonRowToColumnar (22)
#                               :     :           +- Scan csv  (21)
#                               :     :- PhotonProject (30)
#                               :     :  +- PhotonProject (29)
#                               :     :     +- PhotonFilter (28)
#                               :     :        +- PhotonRowToColumnar (27)
#                               :     :           +- Scan csv  (26)
#                               :     :- PhotonProject (35)
#                               :     :  +- PhotonProject (34)
#                               :     :     +- PhotonFilter (33)
#                               :     :        +- PhotonRowToColumnar (32)
#                               :     :           +- Scan csv  (31)
#                               :     :- PhotonProject (40)
#                               :     :  +- PhotonProject (39)
#                               :     :     +- PhotonFilter (38)
#                               :     :        +- PhotonRowToColumnar (37)
#                               :     :           +- Scan csv  (36)
#                               :     :- PhotonProject (45)
#                               :     :  +- PhotonProject (44)
#                               :     :     +- PhotonFilter (43)
#                               :     :        +- PhotonRowToColumnar (42)
#                               :     :           +- Scan csv  (41)
#                               :     :- PhotonProject (50)
#                               :     :  +- PhotonProject (49)
#                               :     :     +- PhotonFilter (48)
#                               :     :        +- PhotonRowToColumnar (47)
#                               :     :           +- Scan csv  (46)
#                               :     :- PhotonProject (55)
#                               :     :  +- PhotonProject (54)
#                               :     :     +- PhotonFilter (53)
#                               :     :        +- PhotonRowToColumnar (52)
#                               :     :           +- Scan csv  (51)
#                               :     :- PhotonProject (60)
#                               :     :  +- PhotonProject (59)
#                               :     :     +- PhotonFilter (58)
#                               :     :        +- PhotonRowToColumnar (57)
#                               :     :           +- Scan csv  (56)
#                               :     :- PhotonProject (65)
#                               :     :  +- PhotonProject (64)
#                               :     :     +- PhotonFilter (63)
#                               :     :        +- PhotonRowToColumnar (62)
#                               :     :           +- Scan csv  (61)
#                               :     :- PhotonProject (70)
#                               :     :  +- PhotonProject (69)
#                               :     :     +- PhotonFilter (68)
#                               :     :        +- PhotonRowToColumnar (67)
#                               :     :           +- Scan csv  (66)
#                               :     :- PhotonProject (75)
#                               :     :  +- PhotonProject (74)
#                               :     :     +- PhotonFilter (73)
#                               :     :        +- PhotonRowToColumnar (72)
#                               :     :           +- Scan csv  (71)
#                               :     +- PhotonProject (80)
#                               :        +- PhotonProject (79)
#                               :           +- PhotonFilter (78)
#                               :              +- PhotonRowToColumnar (77)
#                               :                 +- Scan csv  (76)
#                               +- PhotonShuffleExchangeSource (88)
#                                  +- PhotonShuffleMapStage (87)
#                                     +- PhotonShuffleExchangeSink (86)
#                                        +- PhotonFilter (85)
#                                           +- PhotonRowToColumnar (84)
#                                              +- LocalTableScan (83)
#
#
# (1) Scan csv
# Output [5]: [date#23038, delay#23039, distance#23040, origin#23041, destination#23042]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (2) PhotonRowToColumnar
# Input [5]: [date#23038, delay#23039, distance#23040, origin#23041, destination#23042]
#
# (3) PhotonFilter
# Input [5]: [date#23038, delay#23039, distance#23040, origin#23041, destination#23042]
# Arguments: ((((isnotnull(distance#23040) AND (distance#23040 > 0)) AND isnotnull(origin#23041)) AND isnotnull(destination#23042)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23038 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (4) PhotonProject
# Input [5]: [date#23038, delay#23039, distance#23040, origin#23041, destination#23042]
# Arguments: [delay#23039, distance#23040, origin#23041, cast(gettimestamp(lpad(regexp_replace(cast(date#23038 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#23675]
#
# (5) PhotonProject
# Input [4]: [delay#23039, distance#23040, origin#23041, flight_date#23675]
# Arguments: [delay#23039, distance#23040, origin#23041, year(flight_date#23675) AS year#23677, month(flight_date#23675) AS month#23679, CASE WHEN (delay#23039 > 0) THEN 1 ELSE 0 END AS is_delayed#23683]
#
# (6) Scan csv
# Output [5]: [date#23587, delay#23588, distance#23589, origin#23590, destination#23591]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (7) PhotonRowToColumnar
# Input [5]: [date#23587, delay#23588, distance#23589, origin#23590, destination#23591]
#
# (8) PhotonFilter
# Input [5]: [date#23587, delay#23588, distance#23589, origin#23590, destination#23591]
# Arguments: ((((isnotnull(distance#23589) AND (distance#23589 > 0)) AND isnotnull(origin#23590)) AND isnotnull(destination#23591)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23587 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (9) PhotonProject
# Input [5]: [date#23587, delay#23588, distance#23589, origin#23590, destination#23591]
# Arguments: [delay#23588, distance#23589, origin#23590, cast(gettimestamp(lpad(regexp_replace(cast(date#23587 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#26069]
#
# (10) PhotonProject
# Input [4]: [delay#23588, distance#23589, origin#23590, flight_date#26069]
# Arguments: [delay#23588, distance#23589, origin#23590, year(flight_date#26069) AS year#26084, month(flight_date#26069) AS month#26085, CASE WHEN (delay#23588 > 0) THEN 1 ELSE 0 END AS is_delayed#26086]
#
# (11) Scan csv
# Output [5]: [date#23592, delay#23593, distance#23594, origin#23595, destination#23596]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (12) PhotonRowToColumnar
# Input [5]: [date#23592, delay#23593, distance#23594, origin#23595, destination#23596]
#
# (13) PhotonFilter
# Input [5]: [date#23592, delay#23593, distance#23594, origin#23595, destination#23596]
# Arguments: ((((isnotnull(distance#23594) AND (distance#23594 > 0)) AND isnotnull(origin#23595)) AND isnotnull(destination#23596)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23592 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (14) PhotonProject
# Input [5]: [date#23592, delay#23593, distance#23594, origin#23595, destination#23596]
# Arguments: [delay#23593, distance#23594, origin#23595, cast(gettimestamp(lpad(regexp_replace(cast(date#23592 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#26070]
#
# (15) PhotonProject
# Input [4]: [delay#23593, distance#23594, origin#23595, flight_date#26070]
# Arguments: [delay#23593, distance#23594, origin#23595, year(flight_date#26070) AS year#26087, month(flight_date#26070) AS month#26088, CASE WHEN (delay#23593 > 0) THEN 1 ELSE 0 END AS is_delayed#26089]
#
# (16) Scan csv
# Output [5]: [date#23597, delay#23598, distance#23599, origin#23600, destination#23601]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (17) PhotonRowToColumnar
# Input [5]: [date#23597, delay#23598, distance#23599, origin#23600, destination#23601]
#
# (18) PhotonFilter
# Input [5]: [date#23597, delay#23598, distance#23599, origin#23600, destination#23601]
# Arguments: ((((isnotnull(distance#23599) AND (distance#23599 > 0)) AND isnotnull(origin#23600)) AND isnotnull(destination#23601)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23597 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (19) PhotonProject
# Input [5]: [date#23597, delay#23598, distance#23599, origin#23600, destination#23601]
# Arguments: [delay#23598, distance#23599, origin#23600, cast(gettimestamp(lpad(regexp_replace(cast(date#23597 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#26071]
#
# (20) PhotonProject
# Input [4]: [delay#23598, distance#23599, origin#23600, flight_date#26071]
# Arguments: [delay#23598, distance#23599, origin#23600, year(flight_date#26071) AS year#26090, month(flight_date#26071) AS month#26091, CASE WHEN (delay#23598 > 0) THEN 1 ELSE 0 END AS is_delayed#26092]
#
# (21) Scan csv
# Output [5]: [date#23602, delay#23603, distance#23604, origin#23605, destination#23606]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (22) PhotonRowToColumnar
# Input [5]: [date#23602, delay#23603, distance#23604, origin#23605, destination#23606]
#
# (23) PhotonFilter
# Input [5]: [date#23602, delay#23603, distance#23604, origin#23605, destination#23606]
# Arguments: ((((isnotnull(distance#23604) AND (distance#23604 > 0)) AND isnotnull(origin#23605)) AND isnotnull(destination#23606)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23602 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (24) PhotonProject
# Input [5]: [date#23602, delay#23603, distance#23604, origin#23605, destination#23606]
# Arguments: [delay#23603, distance#23604, origin#23605, cast(gettimestamp(lpad(regexp_replace(cast(date#23602 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#26072]
#
# (25) PhotonProject
# Input [4]: [delay#23603, distance#23604, origin#23605, flight_date#26072]
# Arguments: [delay#23603, distance#23604, origin#23605, year(flight_date#26072) AS year#26093, month(flight_date#26072) AS month#26094, CASE WHEN (delay#23603 > 0) THEN 1 ELSE 0 END AS is_delayed#26095]
#
# (26) Scan csv
# Output [5]: [date#23607, delay#23608, distance#23609, origin#23610, destination#23611]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (27) PhotonRowToColumnar
# Input [5]: [date#23607, delay#23608, distance#23609, origin#23610, destination#23611]
#
# (28) PhotonFilter
# Input [5]: [date#23607, delay#23608, distance#23609, origin#23610, destination#23611]
# Arguments: ((((isnotnull(distance#23609) AND (distance#23609 > 0)) AND isnotnull(origin#23610)) AND isnotnull(destination#23611)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23607 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (29) PhotonProject
# Input [5]: [date#23607, delay#23608, distance#23609, origin#23610, destination#23611]
# ...
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (42) PhotonRowToColumnar
# Input [5]: [date#23622, delay#23623, distance#23624, origin#23625, destination#23626]
#
# (43) PhotonFilter
# Input [5]: [date#23622, delay#23623, distance#23624, origin#23625, destination#23626]
# Arguments: ((((isnotnull(distance#23624) AND (distance#23624 > 0)) AND isnotnull(origin#23625)) AND isnotnull(destination#23626)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23622 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (44) PhotonProject
# Input [5]: [date#23622, delay#23623, distance#23624, origin#23625, destination#23626]
# Arguments: [delay#23623, origin#23625, destination#23626, cast(gettimestamp(lpad(regexp_replace(cast(date#23622 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#26263]
#
# (45) PhotonProject
# Input [4]: [delay#23623, origin#23625, destination#23626, flight_date#26263]
# Arguments: [delay#23623, origin#23625, destination#23626, year(flight_date#26263) AS year#26285, month(flight_date#26263) AS month#26286]
#
# (46) Scan csv
# Output [5]: [date#23627, delay#23628, distance#23629, origin#23630, destination#23631]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (47) PhotonRowToColumnar
# Input [5]: [date#23627, delay#23628, distance#23629, origin#23630, destination#23631]
#
# (48) PhotonFilter
# Input [5]: [date#23627, delay#23628, distance#23629, origin#23630, destination#23631]
# Arguments: ((((isnotnull(distance#23629) AND (distance#23629 > 0)) AND isnotnull(origin#23630)) AND isnotnull(destination#23631)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23627 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (49) PhotonProject
# Input [5]: [date#23627, delay#23628, distance#23629, origin#23630, destination#23631]
# Arguments: [delay#23628, origin#23630, destination#23631, cast(gettimestamp(lpad(regexp_replace(cast(date#23627 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#26264]
#
# (50) PhotonProject
# Input [4]: [delay#23628, origin#23630, destination#23631, flight_date#26264]
# Arguments: [delay#23628, origin#23630, destination#23631, year(flight_date#26264) AS year#26287, month(flight_date#26264) AS month#26288]
#
# (51) Scan csv
# Output [5]: [date#23632, delay#23633, distance#23634, origin#23635, destination#23636]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (52) PhotonRowToColumnar
# Input [5]: [date#23632, delay#23633, distance#23634, origin#23635, destination#23636]
#
# (53) PhotonFilter
# Input [5]: [date#23632, delay#23633, distance#23634, origin#23635, destination#23636]
# Arguments: ((((isnotnull(distance#23634) AND (distance#23634 > 0)) AND isnotnull(origin#23635)) AND isnotnull(destination#23636)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23632 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (54) PhotonProject
# Input [5]: [date#23632, delay#23633, distance#23634, origin#23635, destination#23636]
# Arguments: [delay#23633, origin#23635, destination#23636, cast(gettimestamp(lpad(regexp_replace(cast(date#23632 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#26265]
#
# (55) PhotonProject
# Input [4]: [delay#23633, origin#23635, destination#23636, flight_date#26265]
# Arguments: [delay#23633, origin#23635, destination#23636, year(flight_date#26265) AS year#26289, month(flight_date#26265) AS month#26290]
#
# (56) Scan csv
# Output [5]: [date#23637, delay#23638, distance#23639, origin#23640, destination#23641]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (57) PhotonRowToColumnar
# Input [5]: [date#23637, delay#23638, distance#23639, origin#23640, destination#23641]
#
# (58) PhotonFilter
# Input [5]: [date#23637, delay#23638, distance#23639, origin#23640, destination#23641]
# Arguments: ((((isnotnull(distance#23639) AND (distance#23639 > 0)) AND isnotnull(origin#23640)) AND isnotnull(destination#23641)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23637 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (59) PhotonProject
# Input [5]: [date#23637, delay#23638, distance#23639, origin#23640, destination#23641]
# Arguments: [delay#23638, origin#23640, destination#23641, cast(gettimestamp(lpad(regexp_replace(cast(date#23637 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#26266]
#
# (60) PhotonProject
# Input [4]: [delay#23638, origin#23640, destination#23641, flight_date#26266]
# Arguments: [delay#23638, origin#23640, destination#23641, year(flight_date#26266) AS year#26291, month(flight_date#26266) AS month#26292]
#
# (61) Scan csv
# Output [5]: [date#23642, delay#23643, distance#23644, origin#23645, destination#23646]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (62) PhotonRowToColumnar
# Input [5]: [date#23642, delay#23643, distance#23644, origin#23645, destination#23646]
#
# (63) PhotonFilter
# Input [5]: [date#23642, delay#23643, distance#23644, origin#23645, destination#23646]
# Arguments: ((((isnotnull(distance#23644) AND (distance#23644 > 0)) AND isnotnull(origin#23645)) AND isnotnull(destination#23646)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23642 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (64) PhotonProject
# Input [5]: [date#23642, delay#23643, distance#23644, origin#23645, destination#23646]
# Arguments: [delay#23643, origin#23645, destination#23646, cast(gettimestamp(lpad(regexp_replace(cast(date#23642 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#26267]
#
# (65) PhotonProject
# Input [4]: [delay#23643, origin#23645, destination#23646, flight_date#26267]
# Arguments: [delay#23643, origin#23645, destination#23646, year(flight_date#26267) AS year#26293, month(flight_date#26267) AS month#26294]
#
# (66) Scan csv
# Output [5]: [date#23647, delay#23648, distance#23649, origin#23650, destination#23651]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (67) PhotonRowToColumnar
# Input [5]: [date#23647, delay#23648, distance#23649, origin#23650, destination#23651]
#
# (68) PhotonFilter
# Input [5]: [date#23647, delay#23648, distance#23649, origin#23650, destination#23651]
# Arguments: ((((isnotnull(distance#23649) AND (distance#23649 > 0)) AND isnotnull(origin#23650)) AND isnotnull(destination#23651)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23647 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (69) PhotonProject
# Input [5]: [date#23647, delay#23648, distance#23649, origin#23650, destination#23651]
# Arguments: [delay#23648, origin#23650, destination#23651, cast(gettimestamp(lpad(regexp_replace(cast(date#23647 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#26268]
#
# (70) PhotonProject
# Input [4]: [delay#23648, origin#23650, destination#23651, flight_date#26268]
# Arguments: [delay#23648, origin#23650, destination#23651, year(flight_date#26268) AS year#26295, month(flight_date#26268) AS month#26296]
#
# (71) Scan csv
# Output [5]: [date#23652, delay#23653, distance#23654, origin#23655, destination#23656]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (72) PhotonRowToColumnar
# Input [5]: [date#23652, delay#23653, distance#23654, origin#23655, destination#23656]
#
# (73) PhotonFilter
# Input [5]: [date#23652, delay#23653, distance#23654, origin#23655, destination#23656]
# Arguments: ((((isnotnull(distance#23654) AND (distance#23654 > 0)) AND isnotnull(origin#23655)) AND isnotnull(destination#23656)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23652 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (74) PhotonProject
# Input [5]: [date#23652, delay#23653, distance#23654, origin#23655, destination#23656]
# Arguments: [delay#23653, origin#23655, destination#23656, cast(gettimestamp(lpad(regexp_replace(cast(date#23652 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#26269]
#
# (75) PhotonProject
# Input [4]: [delay#23653, origin#23655, destination#23656, flight_date#26269]
# Arguments: [delay#23653, origin#23655, destination#23656, year(flight_date#26269) AS year#26297, month(flight_date#26269) AS month#26298]
#
# (76) Scan csv
# Output [5]: [date#23657, delay#23658, distance#23659, origin#23660, destination#23661]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/flights/departuredelays.csv]
# PushedFilters: [IsNotNull(distance), GreaterThan(distance,0), IsNotNull(origin), IsNotNull(destination)]
# ReadSchema: struct<date:int,delay:int,distance:int,origin:string,destination:string>
#
# (77) PhotonRowToColumnar
# Input [5]: [date#23657, delay#23658, distance#23659, origin#23660, destination#23661]
#
# (78) PhotonFilter
# Input [5]: [date#23657, delay#23658, distance#23659, origin#23660, destination#23661]
# Arguments: ((((isnotnull(distance#23659) AND (distance#23659 > 0)) AND isnotnull(origin#23660)) AND isnotnull(destination#23661)) AND isnotnull(cast(gettimestamp(lpad(regexp_replace(cast(date#23657 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)))
#
# (79) PhotonProject
# Input [5]: [date#23657, delay#23658, distance#23659, origin#23660, destination#23661]
# Arguments: [delay#23658, origin#23660, destination#23661, cast(gettimestamp(lpad(regexp_replace(cast(date#23657 as string), [^0-9], , 1), 8, 0), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS flight_date#26270]
#
# (80) PhotonProject
# Input [4]: [delay#23658, origin#23660, destination#23661, flight_date#26270]
# Arguments: [delay#23658, origin#23660, destination#23661, year(flight_date#26270) AS year#26299, month(flight_date#26270) AS month#26300]
#
# (81) PhotonUnion
# Arguments: Generic
#
# (82) LocalTableScan
# Output [2]: [month#26236L, season#26237]
# Arguments: [month#26236L, season#26237]
#
# (83) PhotonRowToColumnar
# Input [2]: [month#26236L, season#26237]
#
# (84) PhotonFilter
# Input [2]: [month#26236L, season#26237]
# Arguments: isnotnull(month#26236L)
#
# (85) PhotonShuffleExchangeSink
# Input [2]: [month#26236L, season#26237]
# Arguments: SinglePartition
#
# (86) PhotonShuffleMapStage
# Input [2]: [month#26236L, season#26237]
# Arguments: EXECUTOR_BROADCAST, [id=#91448]
#
# (87) PhotonShuffleExchangeSource
# Input [2]: [month#26236L, season#26237]
#
# (88) PhotonBroadcastHashJoin
# Left keys [1]: [cast(month#23679 as bigint)]
# Right keys [1]: [month#26236L]
# Join type: LeftOuter
# Join condition: None
#
# (89) PhotonProject
# Input [7]: [delay#23039, origin#23041, destination#23042, year#23677, month#23679, month#26236L, season#26237]
# Arguments: [delay#23039, origin#23041, destination#23042, year#23677, season#26237]
#
# (90) PhotonGroupingAgg
# Input [5]: [delay#23039, origin#23041, destination#23042, year#23677, season#26237]
# Arguments: [year#23677, origin#23041, destination#23042, season#26237], [partial_count(1) AS count#26302L, partial_avg(delay#23039) AS (sum#26305, count#26306L)], [count#26301L, sum#26303, count#26304L], [year#23677, origin#23041, destination#23042, season#26237, count#26302L, sum#26305, count#26306L], false
#
# (91) PhotonShuffleExchangeSink
# Input [7]: [year#23677, origin#23041, destination#23042, season#26237, count#26302L, sum#26305, count#26306L]
# Arguments: hashpartitioning(year#23677, origin#23041, destination#23042, season#26237, 1024)
#
# (92) PhotonShuffleMapStage
# Input [7]: [year#23677, origin#23041, destination#23042, season#26237, count#26302L, sum#26305, count#26306L]
# Arguments: ENSURE_REQUIREMENTS, [id=#91457]
#
# (93) PhotonShuffleExchangeSource
# Input [7]: [year#23677, origin#23041, destination#23042, season#26237, count#26302L, sum#26305, count#26306L]
#
# (94) PhotonGroupingAgg
# Input [7]: [year#23677, origin#23041, destination#23042, season#26237, count#26302L, sum#26305, count#26306L]
# Arguments: [year#23677, origin#23041, destination#23042, season#26237], [finalmerge_count(merge count#26302L) AS count(1)#26238L, finalmerge_avg(merge sum#26305, count#26306L) AS avg(delay)#26239], [count(1)#26238L, avg(delay)#26239], [year#23677, origin#23041, destination#23042, season#26237, count(1)#26238L AS flights#24680L, avg(delay)#26239 AS avg_delay_min#24681], true
#
# (95) PhotonFilter
# Input [6]: [year#23677, origin#23041, destination#23042, season#26237, flights#24680L, avg_delay_min#24681]
# Arguments: (cast(flights#24680L as double) >= 16.0)
#
# (96) PhotonProject
# Input [6]: [year#23677, origin#23041, destination#23042, season#26237, flights#24680L, avg_delay_min#24681]
# Arguments: [year#23677, season#26237, origin#23041, destination#23042, flights#24680L, round(avg_delay_min#24681, 1) AS avg_delay_min#25952]
#
# (97) PhotonTopK
# Input [6]: [year#23677, season#26237, origin#23041, destination#23042, flights#24680L, avg_delay_min#25952]
# Arguments: 20, false, false, [avg_delay_min#25952 DESC NULLS LAST], 0
#
# (98) PhotonShuffleExchangeSink
# Input [6]: [year#23677, season#26237, origin#23041, destination#23042, flights#24680L, avg_delay_min#25952]
# Arguments: SinglePartition
#
# (99) PhotonShuffleMapStage
# Input [6]: [year#23677, season#26237, origin#23041, destination#23042, flights#24680L, avg_delay_min#25952]
# Arguments: ENSURE_REQUIREMENTS, [id=#91469]
#
# (100) PhotonShuffleExchangeSource
# Input [6]: [year#23677, season#26237, origin#23041, destination#23042, flights#24680L, avg_delay_min#25952]
#
# (101) PhotonTopK
# Input [6]: [year#23677, season#26237, origin#23041, destination#23042, flights#24680L, avg_delay_min#25952]
# Arguments: 20, false, false, [avg_delay_min#25952 DESC NULLS LAST], 0
#
# (102) PhotonResultStage
# Input [6]: [year#23677, season#26237, origin#23041, destination#23042, flights#24680L, avg_delay_min#25952]
#
# (103) ColumnarToRow
# Input [6]: [year#23677, season#26237, origin#23041, destination#23042, flights#24680L, avg_delay_min#25952]
#
# (104) AdaptiveSparkPlan
# Output [6]: [year#23677, season#26237, origin#23041, destination#23042, flights#24680L, avg_delay_min#25952]
# Arguments: isFinalPlan=false
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.

# %%
# Repartition to different sizes
print("Testing different partition strategies...\n")

# Fewer partitions (4)
df_few = df.repartition(4)
start = time.time()
df_few.filter(col('delay') > 0).count()
few_time = time.time() - start
print(f"✓ Fewer partitions (4): {few_time:.2f}s")

# More partitions (32)
df_many = df.repartition(32)
start = time.time()
df_many.filter(col('delay') > 0).count()
many_time = time.time() - start
print(f"✓ More partitions (32): {many_time:.2f}s")

# Default (let Spark decide)
start = time.time()
df.filter(col('delay') > 0).count()
default_time = time.time() - start
print(f"✓ Default (auto): {default_time:.2f}s")
# Out:
# Testing different partition strategies...
#
# ✓ Fewer partitions (4): 4.69s
# ✓ More partitions (32): 4.83s
# ✓ Default (auto): 3.70s

# %%
# Transformations (lazy): nothing executes yet
lazy_demo = (df_enriched
  .select("origin","destination","distance","delay")
  .filter(F.col("delay") >= 15)                                  # transformation
  .withColumn("speed_mpm", F.col("distance") / F.greatest(F.col("delay"), F.lit(1))))  # transformation

print("No action yet — still lazy.")
lazy_demo.take(5)
# Out:
# No action yet — still lazy.
# [Row(origin='ABE', destination='ATL', distance=602, delay=28, speed_mpm=21.5),
#  Row(origin='ABE', destination='DTW', distance=369, delay=33, speed_mpm=11.181818181818182),
#  Row(origin='ABE', destination='ORD', distance=569, delay=54, speed_mpm=10.537037037037036),
#  Row(origin='ABE', destination='ATL', distance=602, delay=43, speed_mpm=14.0),
#  Row(origin='ABE', destination='ORD', distance=569, delay=83, speed_mpm=6.855421686746988)]

# %%
# Transformations - lazy (just build a plan)
start = time.time()
filtered = df.filter(col('delay') > 100)
selected = filtered.select('origin', 'delay', 'distance')
print(f"Transformations: {time.time() - start:.4f}s")

# Actions - eager (trigger execution)
print("\nAction 1:")
start = time.time()
count = selected.count()
print(f"count() = {count} rows, took {time.time() - start:.2f}s")

print("\nAction 2:")
start = time.time()
selected.show(5)
print(f"show() took {time.time() - start:.2f}s")

print("\nNotice: Each action re-executes the transformations!")
# Out:
# Transformations: 0.0005s
#
# Action 1:
# count() = 733760 rows, took 3.68s
#
# Action 2:
# +------+-----+--------+
# |origin|delay|distance|
# +------+-----+--------+
# |   ABE|  151|     369|
# |   ABE|  127|     602|
# |   ABE|  333|     602|
# |   ABE|  219|     569|
# |   ABE|  180|     602|
# +------+-----+--------+
# only showing top 5 rows
# show() took 0.61s
#
# Notice: Each action re-executes the transformations!

# %% [markdown]
# Spark optimized the pipeline primarily through column pruning, predicate pushdown, and operator fusion. Because we selected only the needed columns up front, the physical plan shows a Parquet/CSV scan that reads fewer fields. In the .explain(mode="formatted") output for the Parquet step, the scan node lists PushedFilters (e.g., GreaterThan(distance, 0), IsNotNull(origin), In(origin, [JFK,LAX,ATL])) and PartitionFilters when filtering by year and month, confirming that filters were applied at the data source to minimize I/O. Aggregations are executed under WholeStageCodegen, reducing JVM overhead, and the small month→season lookup uses a BroadcastHashJoin, avoiding a shuffle on the dimension side.
#
# The Spark UI’s SQL Query Details reveals that the main bottlenecks were the wide shuffles during groupBy(year, month, origin) and groupBy(year, origin, destination, season), as well as any global orderBy used for top-N results. Another minor cost stemmed from parsing dates in the raw file; we addressed malformed values via try_to_date, then dropped NULL dates early so bad rows wouldn’t propagate. When using CSV as the source, pushdown is limited, so converting an intermediate to Parquet both improved scans and made the pushdown behavior visible (smaller bytes-read in the UI).
#
# To optimize, we (1) wrote filters early (flight_date IS NOT NULL, distance > 0, required columns non-null) to shrink the working set; (2) enforced column pruning by selecting only the fields used downstream; (3) broadcast the tiny month→season mapping to eliminate a join shuffle; (4) tuned parallelism with spark.sql.files.maxPartitionBytes=128m and a reasonable spark.sql.shuffle.partitions; and (5) repartitioned and wrote partitioned Parquet by year,month (and year,origin) so future queries benefit from partition pruning and avoid unnecessary shuffles. Together, these choices cut input I/O, reduced shuffle volume, and sped up repeated analysis steps without changing business logic.
